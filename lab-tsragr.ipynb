# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import time
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup


def f(df: pd.DataFrame, base_url: str) -> pd.DataFrame:
    df.index = base_url + df["path"]
    return df


class TSragr:
    def __init__(self, data: str = None) -> None:

        if isinstance(data, str):
            self._baseurl = data

            r = requests.get(data)
            r.raise_for_status()

            soup = BeautifulSoup(r.content, "lxml").find_all("a")

            if soup[0].text == "Parent Directory":
                soup = soup[1:]

            self._soup = pd.DataFrame([x.text for x in soup], columns=["path"]).pipe(f, base_url=data)

    def __repr__(self) -> str:
        return f"{self._baseurl}\n" + self._soup.__repr__()

    def __getitem__(self, args) -> "TSragr":
        self._soup = self._soup[args]
        return self

    @property
    def url(self):
        return self._baseurl + "/"

    def navto(self, *args: str) -> "TSragr":
        return TSragr(self._baseurl + "/".join(args))

    def navup(self) -> "TSragr":
        return TSragr(re.match(r"^(.*[\/])", self._baseurl).group())

    def inav(self, index: int):
        return TSragr(self.url + self._soup[index])

    def download(self, save_to="./", wait: float = 10):

        soup = self._soup.copy()
        soup.index = self.url + self._soup

        for url, filename in soup.items():
            print("DOWNLAODING FILE")
            local_filename = save_to + filename
            with requests.get(url, stream=True) as r:
                r.raise_for_status()
                with open(local_filename, "wb") as f:
                    for chunk in r.iter_content(chunk_size=8192):
                        f.write(chunk)

            print("FILE SAVED")
            time.sleep(60 * wait)


ragr = TSragr("https://nomads.ncep.noaa.gov/pub/data/nccf/")

ragr
# Out:
# https://nomads.ncep.noaa.gov/pub/data/nccf/
#                                                                path
# path
# https://nomads.ncep.noaa.gov/pub/data/nccf/charts/          charts/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/                com/
# https://nomads.ncep.noaa.gov/pub/data/nccf/dcom/              dcom/
# https://nomads.ncep.noaa.gov/pub/data/nccf/nono...  nonoperational/
# https://nomads.ncep.noaa.gov/pub/data/nccf/pcom/              pcom/
# https://nomads.ncep.noaa.gov/pub/data/nccf/radar/            radar/

# %%
url = "https://nomads.ncep.noaa.gov/pub/data/"
r = requests.get(url)
r.raise_for_status()

soup = BeautifulSoup(r.content, "lxml").find_all("a")
import numpy as np


def read_directory(df: pd.DataFrame) -> pd.DataFrame:
    def generate():
        base = ("https://nomads.ncep.noaa.gov/pub/", "data/")
        index =[]
        for path in df["path"]:
            r = requests.get(path)
            r.raise_for_status()
            soup = BeautifulSoup(r.content, "lxml").find_all("a")
            paths = []
            files = []
            for x in soup:
                text: str = x.text
                if text != "Parent Directory":
                    if text.endswith("/"):
                        paths.append(text)
                    else:
                        files.append(text)
            yield {"paths": paths, "files": files}
            # yield {"PATH" if x.text.endswith("/") else "FILE": x.text for x in soup if x.text != "Parent Directory"}

    return pd.DataFrame(
        tuple(generate()), index=pd.MultiIndex.from_tuples([("https://nomads.ncep.noaa.gov/pub/", "data/")])
    )  # pd.DataFrame(tuple(generate()), index=[url], axis=1)


# def read():

pd.DataFrame([url], columns=["path"]).pipe(read_directory)
# Out:
#                                           paths   files
# https://nomads.ncep.noaa.gov/pub data/  [nccf/]  [DSRC]

# %%
import time
import re
import pandas as pd
import requests
from bs4 import BeautifulSoup
path = "https://nomads.ncep.noaa.gov/pub/data/"


def soup_handle(soup: list[str]):
    for url in soup:
        if url.endswith("/"):
            # print(url)
            ...
            yield tuple(get_path([url]))
        else:
            yield url


def get_path(paths):
    for path in paths:
        print(path)
        r = requests.get(path)
        r.raise_for_status()
        soup = BeautifulSoup(r.content, "lxml").find_all("a")
        yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))


e = tuple(get_path(["https://nomads.ncep.noaa.gov/pub/data/"]))
e
# Out:
# https://nomads.ncep.noaa.gov/pub/data/
# https://nomads.ncep.noaa.gov/pub/data/nccf/
# https://nomads.ncep.noaa.gov/pub/data/nccf/charts/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/557ww/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/557ww/prod/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/557ww/prod/557ww.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/557ww/prod/557ww.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220520/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220520/io932022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220520/sh262022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220520/wp912022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220601/al912022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220602/al912022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/amsu_estimation/v1.3/amsu_estimation.20220602/wp942022/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/ak.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/ak.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/AK.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/AK.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/aqm.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/aqm.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/cs.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/cs.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/hi.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/hi.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/HI.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/prod/HI.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/ak.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/ak.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/AK.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/AK.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/aqm.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/aqm.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/cs.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/cs.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/hi.20220601/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/hi.20220602/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/HI.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/aqm/v6.1/HI.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/arch/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/arch/prod/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/arch/prod/syndat/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/00/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/00/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/00/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/00/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/01/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/01/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/01/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/02/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/02/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/02/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/03/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/03/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/03/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/04/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/04/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/04/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/05/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/05/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/05/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/06/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/06/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/06/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/06/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/07/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/07/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/07/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/08/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/08/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/08/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/09/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/09/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/09/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/10/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/10/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/10/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/11/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/11/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/11/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/12/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/12/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/12/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/12/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/13/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/13/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/13/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/14/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/14/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/14/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/15/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/15/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/15/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/16/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/16/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/16/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/17/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/17/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/17/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/18/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/18/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/18/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/18/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/19/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/19/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/19/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/20/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/20/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/20/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/21/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/21/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/21/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/22/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/22/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/22/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/23/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/23/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220604/23/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/00/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/00/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/00/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/00/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/01/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/01/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/01/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/02/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/02/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/02/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/03/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/03/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/03/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/04/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/04/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/04/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/05/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/05/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/05/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/06/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/06/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/06/qmd/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/06/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/07/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/07/core/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/07/text/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/08/
# https://nomads.ncep.noaa.gov/pub/data/nccf/com/blend/prod/blend.20220605/08/core/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22951/2551403636.py in <cell line: 30>()
#      28
#      29
# ---> 30 e = tuple(get_path(["https://nomads.ncep.noaa.gov/pub/data/"]))
#      31 e
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      25         soup = BeautifulSoup(r.content, "lxml").find_all("a")
#      26         # time.sleep(2)
# ---> 27         yield tuple(soup_handle([path + x.text for x in soup if x.text != "Parent Directory"]))
#      28
#      29
#
# /tmp/ipykernel_22951/2551403636.py in soup_handle(soup)
#      12             # print(url)
#      13             ...
# ---> 14             yield tuple(get_path([url]))
#      15         else:
#      16             yield url
#
# /tmp/ipykernel_22951/2551403636.py in get_path(paths)
#      20     for path in paths:
#      21         print(path)
# ---> 22         r = requests.get(path)
#      23
#      24         r.raise_for_status()
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1038         # Force connect early to allow us to validate the connection.
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#    1042         if not conn.is_verified:
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~/miniconda3/envs/wxlab/lib/python3.10/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:
